# %% [markdown]
# # 9강 정형데이터 분류 베이스라인 모델 3 하이퍼 파라미터 튜닝
#
# - 세번째 베이스라인 모델에서 LightGBM에 Optuna를 이용해서 하이퍼 파라미터 튜닝 적용

# %% [markdown]
# ## Function 정의
#
# - seed_everything() : seed 고정 함수
# - generate_label() : label 생성 함수
# - print_score() : 평가지표 출력 함수
# - feature_preprocessing() : 데이터 전처리 함수(label encoding, 결측치 처리)
# - feature_engineering1() : 피처 엔지니어링 함수
# - make_lgb_oof_prediction() : LightGBM cross validation out of fold train/predict 함수
# - plot_feature_importances() : 피처 중요도 플롯 함수
# - objective() : optuna objective 함수

# %% [markdown]
# ## Library Import

# %%
# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

import os, sys, gc, warnings, random

import datetime
import dateutil.relativedelta

# Data manipulation
import pandas as pd 
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, precision_recall_curve, roc_curve
from sklearn.model_selection import train_test_split, cross_val_score, KFold, StratifiedKFold, GroupKFold
from sklearn.ensemble import RandomForestClassifier

import lightgbm as lgb
import optuna

from tqdm.notebook import trange, tqdm

from IPython.display import display

# %matplotlib inline

pd.options.display.max_rows = 10000
pd.options.display.max_columns = 1000
pd.options.display.max_colwidth = 1000

# %% [markdown]
# ## Fix Seed 함수 정의

# %%
def seed_everything(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
SEED = 42
seed_everything(SEED)

# %% [markdown]
# ## 레이블 생성 함수 정의
#
# - 레이블 생성 함수는 연월을 인자로 받아서 고객 아이디별로 총 구매액이 인자로 받는 구매액 임계값을 넘는지 여부를 바이너리 레이블로 생성하는 함수

# %%
TOTAL_THRES = 300

'''
    입력인자로 받는 year_month에 대해 고객 ID별로 총 구매액이
    구매액 임계값을 넘는지 여부의 binary label을 생성하는 함수
'''
def generate_label(df, year_month, total_thres=TOTAL_THRES, print_log=False):
    df = df.copy()
    
    # year_month에 해당하는 label 데이터 생성
    df['year_month'] = df['order_date'].dt.strftime('%Y-%m')
    df.reset_index(drop=True, inplace=True)

    # year_month 이전 월의 고객 ID 추출
    cust = df[df['year_month']<year_month]['customer_id'].unique()
    # year_month에 해당하는 데이터 선택
    df = df[df['year_month']==year_month]
    
    # label 데이터프레임 생성
    label = pd.DataFrame({'customer_id':cust})
    label['year_month'] = year_month
    
    # year_month에 해당하는 고객 ID의 구매액의 합 계산
    grped = df.groupby(['customer_id','year_month'], as_index=False)[['total']].sum()
    
    # label 데이터프레임과 merge하고 구매액 임계값을 넘었는지 여부로 label 생성
    label = label.merge(grped, on=['customer_id','year_month'], how='left')
    label['total'].fillna(0.0, inplace=True)
    label['label'] = (label['total'] > total_thres).astype(int)

    # 고객 ID로 정렬
    label = label.sort_values('customer_id').reset_index(drop=True)
    if print_log: print(f'{year_month} - final label shape: {label.shape}')
    
    return label

# %% [markdown]
# ## 평가지표 출력 함수 정의

# %%
def print_score(label, pred, prob_thres=0.5):
    print('Precision: {:.5f}'.format(precision_score(label, pred>prob_thres)))
    print('Recall: {:.5f}'.format(recall_score(label, pred>prob_thres)))
    print('F1 Score: {:.5f}'.format(f1_score(label, pred>prob_thres)))
    print('ROC AUC Score: {:.5f}'.format(roc_auc_score(label, pred)))

# %% [markdown]
# ## 데이터 전처리 함수 정의
# - 범주형 변수 레이블 인코딩
# - 결측치 중위값으로 채움

# %%
def feature_preprocessing(train, test, features, do_imputing=True):
    x_tr = train.copy()
    x_te = test.copy()
    
    # 범주형 피처 이름을 저장할 변수
    cate_cols = []

    # 레이블 인코딩
    for f in features:
        if x_tr[f].dtype.name == 'object': # 데이터 타입이 object(str)이면 레이블 인코딩
            cate_cols.append(f)
            le = LabelEncoder()
            # train + test 데이터를 합쳐서 레이블 인코딩 함수에 fit
            le.fit(list(x_tr[f].values) + list(x_te[f].values))
            
            # train 데이터 레이블 인코딩 변환 수행
            x_tr[f] = le.transform(list(x_tr[f].values))
            
            # test 데이터 레이블 인코딩 변환 수행
            x_te[f] = le.transform(list(x_te[f].values))

    print('categorical feature:', cate_cols)

    if do_imputing:
        # 중위값으로 결측치 채우기
        imputer = SimpleImputer(strategy='median')

        x_tr[features] = imputer.fit_transform(x_tr[features])
        x_te[features] = imputer.transform(x_te[features])
    
    return x_tr, x_te

# %% [markdown]
# ## 피처 엔지니어링 함수 정의
# - Pandas groupby aggregation 함수를 사용한 피처 엔지니어링

# %%
def feature_engineering1(df, year_month):
    df = df.copy()
    
    # year_month 이전 월 계산
    d = datetime.datetime.strptime(year_month, "%Y-%m")
    prev_ym = d - dateutil.relativedelta.relativedelta(months=1)
    prev_ym = prev_ym.strftime('%Y-%m')
    
    # train, test 데이터 선택
    train = df[df['order_date'] < prev_ym]
    test = df[df['order_date'] < year_month]
    
    # train, test 레이블 데이터 생성
    train_label = generate_label(df, prev_ym)[['customer_id','year_month','label']]
    test_label = generate_label(df, year_month)[['customer_id','year_month','label']]
    
    # group by aggregation 함수 선언
    agg_func = ['mean','max','min','sum','count','std','skew']
    all_train_data = pd.DataFrame()
    
    for i, tr_ym in enumerate(train_label['year_month'].unique()):
        # group by aggretation 함수로 train 데이터 피처 생성
        train_agg = train.loc[train['order_date'] < tr_ym].groupby(['customer_id']).agg(agg_func)

        # 멀티 레벨 컬럼을 사용하기 쉽게 1 레벨 컬럼명으로 변경
        new_cols = []
        for col in train_agg.columns.levels[0]:
            for stat in train_agg.columns.levels[1]:
                new_cols.append(f'{col}-{stat}')

        train_agg.columns = new_cols
        train_agg.reset_index(inplace = True)
        
        train_agg['year_month'] = tr_ym
        
        all_train_data = all_train_data.append(train_agg)
    
    all_train_data = train_label.merge(all_train_data, on=['customer_id', 'year_month'], how='left')
    features = all_train_data.drop(columns=['customer_id', 'label', 'year_month']).columns
    
    # group by aggretation 함수로 test 데이터 피처 생성
    test_agg = test.groupby(['customer_id']).agg(agg_func)
    test_agg.columns = new_cols
    
    test_data = test_label.merge(test_agg, on=['customer_id'], how='left')

    # train, test 데이터 전처리
    x_tr, x_te = feature_preprocessing(all_train_data, test_data, features)
    
    print('x_tr.shape', x_tr.shape, ', x_te.shape', x_te.shape)
    
    return x_tr, x_te, all_train_data['label'], features

# %% [markdown]
# ## LightGBM cross validation out of fold train/predict 함수 정의

# %%
def make_lgb_oof_prediction(train, y, test, features, categorical_features='auto', model_params=None, folds=10):
    x_train = train[features]
    x_test = test[features]
    
    # 테스트 데이터 예측값을 저장할 변수
    test_preds = np.zeros(x_test.shape[0])
    
    # Out Of Fold Validation 예측 데이터를 저장할 변수
    y_oof = np.zeros(x_train.shape[0])
    
    # 폴드별 평균 Validation 스코어를 저장할 변수
    score = 0
    
    # 피처 중요도를 저장할 데이터 프레임 선언
    fi = pd.DataFrame()
    fi['feature'] = features
    
    # Stratified K Fold 선언
    skf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=SEED)

    for fold, (tr_idx, val_idx) in enumerate(skf.split(x_train, y)):
        # train index, validation index로 train 데이터를 나눔
        x_tr, x_val = x_train.loc[tr_idx, features], x_train.loc[val_idx, features]
        y_tr, y_val = y[tr_idx], y[val_idx]
        
        print(f'fold: {fold+1}, x_tr.shape: {x_tr.shape}, x_val.shape: {x_val.shape}')

        # LightGBM 데이터셋 선언
        dtrain = lgb.Dataset(x_tr, label=y_tr)
        dvalid = lgb.Dataset(x_val, label=y_val)
        
        # LightGBM 모델 훈련
        clf = lgb.train(
            model_params,
            dtrain,
            valid_sets=[dtrain, dvalid], # Validation 성능을 측정할 수 있도록 설정
            categorical_feature=categorical_features,
            verbose_eval=200
        )

        # Validation 데이터 예측
        val_preds = clf.predict(x_val)
        
        # Validation index에 예측값 저장 
        y_oof[val_idx] = val_preds
        
        # 폴드별 Validation 스코어 출력
        print(f"Fold {fold + 1} | AUC: {roc_auc_score(y_val, val_preds)}")
        print('-'*80)

        # score 변수에 폴드별 평균 Validation 스코어 저장
        score += roc_auc_score(y_val, val_preds) / folds
        
        # 테스트 데이터 예측하고 평균해서 저장
        test_preds += clf.predict(x_test) / folds
        
        # 폴드별 피처 중요도 저장
        fi[f'fold_{fold+1}'] = clf.feature_importance()

        del x_tr, x_val, y_tr, y_val
        gc.collect()
        
    print(f"\nMean AUC = {score}") # 폴드별 평균 Validation 스코어 출력
    print(f"OOF AUC = {roc_auc_score(y, y_oof)}") # Out Of Fold Validation 스코어 출력
        
    # 폴드별 피처 중요도 평균값 계산해서 저장
    fi_cols = [col for col in fi.columns if 'fold_' in col]
    fi['importance'] = fi[fi_cols].mean(axis=1)
    
    return y_oof, test_preds, fi

# %% [markdown]
# ## 피처 중요도 플롯 함수 정의

# %%
def plot_feature_importances(df, n=20, color='blue', figsize=(12,8)):
    # 피처 중요도 순으로 내림차순 정렬
    df = df.sort_values('importance', ascending = False).reset_index(drop = True)
    
    # 피처 중요도 정규화 및 누적 중요도 계산
    df['importance_normalized'] = df['importance'] / df['importance'].sum()
    df['cumulative_importance'] = np.cumsum(df['importance_normalized'])
    
    plt.rcParams['font.size'] = 12
    plt.style.use('fivethirtyeight')
    # 피처 중요도 순으로 n개까지 바플롯으로 그리기
    df.loc[:n, :].plot.barh(y='importance_normalized', 
                            x='feature', color=color, 
                            edgecolor='k', figsize=figsize,
                            legend=False)

    plt.xlabel('Normalized Importance', size=18); plt.ylabel(''); 
    plt.title(f'Top {n} Most Important Features', size=18)
    plt.gca().invert_yaxis()
    
    return df

# %% [markdown]
# ## Train 데이터 읽기
# - 9개의 feature를 가진 780502개의 train data

# %%
data = pd.read_csv("../input/train.csv", parse_dates=["order_date"])
print(data.shape)  # data shape 확인
data.head()
# Out:
# (780502, 9)
#   order_id product_id                          description  quantity  \
# 0   489434      85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1   489434     79323P                   PINK CHERRY LIGHTS        12
# 2   489434     79323W                  WHITE CHERRY LIGHTS        12
# 3   489434      22041         RECORD FRAME 7" SINGLE SIZE         48
# 4   489434      21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            order_date    price  customer_id         country   total
# 0 2009-12-01 07:45:00  11.4675        13085  United Kingdom  137.61
# 1 2009-12-01 07:45:00  11.1375        13085  United Kingdom  133.65
# 2 2009-12-01 07:45:00  11.1375        13085  United Kingdom  133.65
# 3 2009-12-01 07:45:00   3.4650        13085  United Kingdom  166.32
# 4 2009-12-01 07:45:00   2.0625        13085  United Kingdom   49.50

# %% [markdown]
# ## Pandas info() 함수로 데이터 타입 및 null 체크

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780502 entries, 0 to 780501
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   order_id     780502 non-null  object
#  1   product_id   780502 non-null  object
#  2   description  780502 non-null  object
#  3   quantity     780502 non-null  int64
#  4   order_date   780502 non-null  datetime64[ns]
#  5   price        780502 non-null  float64
#  6   customer_id  780502 non-null  int64
#  7   country      780502 non-null  object
#  8   total        780502 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 53.6+ MB

# %% [markdown]
# ## Pandas isna(), sum() 함수로 null 데이터 개수 체크

# %%
data.isna().sum()
# Out:
# order_id       0
# product_id     0
# description    0
# quantity       0
# order_date     0
# price          0
# customer_id    0
# country        0
# total          0
# dtype: int64

# %% [markdown]
# ## Pandas describe() 함수에 include='all' 인자 설정으로 수치형, 범주형 데이터 기본 통계량 확인

# %%
data.describe(include='all')
# Out:
#        order_id product_id                         description       quantity  \
# count    780502     780502                              780502  780502.000000
# unique    43955       4645                                5297            NaN
# top      576339     85123A  WHITE HANGING HEART T-LIGHT HOLDER            NaN
# freq        542       5096                                5096            NaN
# first       NaN        NaN                                 NaN            NaN
# last        NaN        NaN                                 NaN            NaN
# mean        NaN        NaN                                 NaN      12.623307
# std         NaN        NaN                                 NaN     143.906302
# min         NaN        NaN                                 NaN  -74215.000000
# 25%         NaN        NaN                                 NaN       2.000000
# 50%         NaN        NaN                                 NaN       5.000000
# 75%         NaN        NaN                                 NaN      12.000000
# max         NaN        NaN                                 NaN   74215.000000
#
#                  order_date          price    customer_id         country  \
# count                780502  780502.000000  780502.000000          780502
# unique                40615            NaN            NaN              41
# top     2011-11-14 15:27:00            NaN            NaN  United Kingdom
# freq                    543            NaN            NaN          700317
# first   2009-12-01 07:45:00            NaN            NaN             NaN
# last    2011-11-30 17:42:00            NaN            NaN             NaN
# mean                    NaN       6.140931   15313.393466             NaN
# std                     NaN     119.042266    1695.765797             NaN
# min                     NaN       0.000000   12346.000000             NaN
# 25%                     NaN       2.062500   13963.000000             NaN
# 50%                     NaN       3.217500   15239.000000             NaN
# 75%                     NaN       6.187500   16788.000000             NaN
# max                     NaN   64300.500000   18287.000000             NaN
#
#                 total
# count   780502.000000
# unique            NaN
# top               NaN
# freq              NaN
# first             NaN
# last              NaN
# mean        33.715373
# std        274.207403
# min    -127352.940000
# 25%          7.260000
# 50%         19.470000
# 75%         32.175000
# max     127352.940000

# %% [markdown]
# ## 2011년 11월 Label 데이터 생성

# %%
label_2011_11 = generate_label(data, '2011-11')['label']

# %% [markdown]
# ## Label 데이터 분포 플롯

# %%
sns.countplot(label_2011_11);
label_2011_11.value_counts()
# Out:
# 0    4534
# 1    1188
# Name: label, dtype: int64

# %% [markdown]
# ## LightGBM Hyperparameter 선언
# - early stopping 기능을 사용하기 위해 n_estimators, early_stopping_rounds 설정

# %%
model_params = {
    'objective': 'binary', # 이진 분류
    'boosting_type': 'gbdt',
    'metric': 'auc', # 평가 지표 설정
    'feature_fraction': 0.8, # 피처 샘플링 비율
    'bagging_fraction': 0.8, # 데이터 샘플링 비율
    'bagging_freq': 1,
    'n_estimators': 10000, # 트리 개수
    'early_stopping_rounds': 100,
    'seed': SEED,
    'verbose': -1,
    'n_jobs': -1,    
}

# %% [markdown]
# ## 2011년 12월 LightGBM 베이스라인 모델 예측
# - Validation 성능 측정

# %%
train, test, y, features = feature_engineering1(data, '2011-12')
y_oof, test_preds, fi = make_lgb_oof_prediction(train, y, test, features, model_params=lgb_params)
# Out:
# categorical feature: []
# x_tr.shape (5722, 24) , x_te.shape (5914, 24)
# fold: 1, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [24]	training's auc: 0.902047	valid_1's auc: 0.76602
# Fold 1 | AUC: 0.7660200644134305
# --------------------------------------------------------------------------------
# fold: 2, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [35]	training's auc: 0.926121	valid_1's auc: 0.790915
# Fold 2 | AUC: 0.790915485136786
# --------------------------------------------------------------------------------
# fold: 3, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [10]	training's auc: 0.852035	valid_1's auc: 0.794034
# Fold 3 | AUC: 0.7940341969685657
# --------------------------------------------------------------------------------
# fold: 4, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [12]	training's auc: 0.86607	valid_1's auc: 0.750737
# Fold 4 | AUC: 0.7507373254685283
# --------------------------------------------------------------------------------
# fold: 5, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [35]	training's auc: 0.925663	valid_1's auc: 0.772664
# Fold 5 | AUC: 0.7726640325004173
# --------------------------------------------------------------------------------
# fold: 6, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [40]	training's auc: 0.937477	valid_1's auc: 0.793812
# Fold 6 | AUC: 0.7938115643608437
# --------------------------------------------------------------------------------
# fold: 7, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [4]	training's auc: 0.827173	valid_1's auc: 0.7946
# Fold 7 | AUC: 0.7945999591889736
# --------------------------------------------------------------------------------
# fold: 8, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [11]	training's auc: 0.858855	valid_1's auc: 0.764066
# Fold 8 | AUC: 0.7640658912571651
# --------------------------------------------------------------------------------
# fold: 9, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [10]	training's auc: 0.854105	valid_1's auc: 0.779927
# Fold 9 | AUC: 0.7799265401524849
# --------------------------------------------------------------------------------
# fold: 10, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [20]	training's auc: 0.886854	valid_1's auc: 0.764075
# Fold 10 | AUC: 0.7640751664904373
# --------------------------------------------------------------------------------
#
# Mean AUC = 0.7770850225937632
# OOF AUC = 0.7672395547891799

# %%
print_score(label_2011_11, y_oof)
# Out:
# Precision: 0.65435
# Recall: 0.20875
# F1 Score: 0.31653
# ROC AUC Score: 0.76724

# %% [markdown]
# ## 2011년 12월 LightGBM 베이스라인 모델 예측 데이터 분포

# %%
sns.distplot(test_preds)
plt.show()

# %% [markdown]
# ## LightGBM 피처 중요도 플롯

# %%
fi = plot_feature_importances(fi)

# %% [markdown]
# ## Optuna Objective Function 정의

# %%
def objective(trial, label=label_2011_11):
    lgb_params = {
        'objective': 'binary', # 이진 분류
        'boosting_type': 'gbdt',
        'num_leaves': trial.suggest_int('num_leaves', 2, 256), # num_leaves 값을 2-256까지 정수값 중에 사용
        'max_bin': trial.suggest_int('max_bin', 128, 256), # max_bin 값을 128-256까지 정수값 중에 사용
        # min_data_in_leaf 값을 10-40까지 정수값 중에 사용
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 10, 40),
        # 피처 샘플링 비율을 0.4-1.0까지 중에 uniform 분포로 사용
        'feature_fraction': trial.suggest_uniform('feature_fraction', 0.4, 1.0),
        # 데이터 샘플링 비율을 0.4-1.0까지 중에 uniform 분포로 사용
        'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.4, 1.0),
        # 데이터 샘플링 횟수를 1-7까지 정수값 중에 사용
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
        'n_estimators': 10000, # 트리 개수
        'early_stopping_rounds': 100,
        # L1 값을 1e-8-10.0까지 로그 uniform 분포로 사용
        'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
        # L2 값을 1e-8-10.0까지 로그 uniform 분포로 사용
        'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
        'seed': SEED,
        'verbose': -1,
        'n_jobs': -1,    
    }
    
    # oof prediction 함수 호출해서 out of fold validation 예측값을 얻어옴
    y_oof, test_preds, fi = make_lgb_oof_prediction(train, y, test, features, model_params=lgb_params)
    
    # Validation 스코어 계산
    val_auc = roc_auc_score(label, y_oof)
    
    return val_auc

# %% [markdown]
# ## Optuna study 생성, auc이기 때문에 최대화 하는 방향으로 하이퍼 파라미터 탐색

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=10) # 10회 동안 하이퍼 파라미터 탐색
# Out:
# [I 2021-03-22 02:42:18,734] A new study created in memory with name: no-name-1a5f1ebe-4a39-40b8-b94a-3751714d4342
# fold: 1, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [16]	training's binary_logloss: 0.391302	valid_1's binary_logloss: 0.437728
# Fold 1 | AUC: 0.7569318476289194
# --------------------------------------------------------------------------------
# fold: 2, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [30]	training's binary_logloss: 0.366634	valid_1's binary_logloss: 0.412168
# Fold 2 | AUC: 0.7838077962462519
# --------------------------------------------------------------------------------
# fold: 3, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [14]	training's binary_logloss: 0.400704	valid_1's binary_logloss: 0.416298
# Fold 3 | AUC: 0.7796516837153737
# --------------------------------------------------------------------------------
# fold: 4, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [21]	training's binary_logloss: 0.381507	valid_1's binary_logloss: 0.433737
# Fold 4 | AUC: 0.7643078473829613
# --------------------------------------------------------------------------------
# fold: 5, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [25]	training's binary_logloss: 0.372473	valid_1's binary_logloss: 0.432359
# Fold 5 | AUC: 0.7632774964290352
# --------------------------------------------------------------------------------
# fold: 6, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [26]	training's binary_logloss: 0.369047	valid_1's binary_logloss: 0.415816
# Fold 6 | AUC: 0.7911588476450183
# --------------------------------------------------------------------------------
# fold: 7, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [21]	training's binary_logloss: 0.386957	valid_1's binary_logloss: 0.419148
# Fold 7 | AUC: 0.7780622182647893
# --------------------------------------------------------------------------------
# fold: 8, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [21]	training's binary_logloss: 0.37867	valid_1's binary_logloss: 0.440001
# Fold 8 | AUC: 0.7612925965088022
# --------------------------------------------------------------------------------
# fold: 9, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [36]	training's binary_logloss: 0.353798	valid_1's binary_logloss: 0.406491
# Fold 9 | AUC: 0.7988201903277867
# --------------------------------------------------------------------------------
# fold: 10, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [17]	training's binary_logloss: 0.388516	valid_1's binary_logloss: 0.427758
# Fold 10 | AUC: 0.7725063535347914
# --------------------------------------------------------------------------------
# [I 2021-03-22 02:42:21,150] Trial 0 finished with value: 0.7751074374089372 and parameters: {'num_leaves': 54, 'max_bin': 150, 'min_data_in_leaf': 39, 'feature_fraction': 0.9048899754250462, 'bagging_fraction': 0.4185373766076864, 'bagging_freq': 6, 'lambda_l1': 1.4905429345073014, 'lambda_l2': 1.5708318504983804e-08}. Best is trial 0 with value: 0.7751074374089372.
# Mean AUC = 0.774981687768373
# OOF AUC = 0.7751074374089372
# fold: 1, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [12]	training's binary_logloss: 0.369632	valid_1's binary_logloss: 0.445277
# Fold 1 | AUC: 0.7433457964683672
# --------------------------------------------------------------------------------
# fold: 2, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [25]	training's binary_logloss: 0.318174	valid_1's binary_logloss: 0.421899
# Fold 2 | AUC: 0.7754599637211712
# --------------------------------------------------------------------------------
# fold: 3, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [21]	training's binary_logloss: 0.331097	valid_1's binary_logloss: 0.415555
# Fold 3 | AUC: 0.779810348689614
# --------------------------------------------------------------------------------
# fold: 4, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [13]	training's binary_logloss: 0.363552	valid_1's binary_logloss: 0.464708
# Fold 4 | AUC: 0.7040804898081088
# --------------------------------------------------------------------------------
# fold: 5, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [12]	training's binary_logloss: 0.377728	valid_1's binary_logloss: 0.439224
# Fold 5 | AUC: 0.7571929434025266
# --------------------------------------------------------------------------------
# fold: 6, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [21]	training's binary_logloss: 0.330721	valid_1's binary_logloss: 0.421753
# Fold 6 | AUC: 0.7836088077615152
# --------------------------------------------------------------------------------
# fold: 7, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [21]	training's binary_logloss: 0.329767	valid_1's binary_logloss: 0.420111
# Fold 7 | AUC: 0.7859090656130001
# --------------------------------------------------------------------------------
# fold: 8, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [14]	training's binary_logloss: 0.362981	valid_1's binary_logloss: 0.445617
# Fold 8 | AUC: 0.7423340197005954
# --------------------------------------------------------------------------------
# fold: 9, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [19]	training's binary_logloss: 0.338281	valid_1's binary_logloss: 0.421652
# Fold 9 | AUC: 0.7708831877121709
# --------------------------------------------------------------------------------
# fold: 10, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# [I 2021-03-22 02:42:25,112] Trial 1 finished with value: 0.7626329461353722 and parameters: {'num_leaves': 162, 'max_bin': 254, 'min_data_in_leaf': 20, 'feature_fraction': 0.6358564498775215, 'bagging_fraction': 0.43458411575409206, 'bagging_freq': 6, 'lambda_l1': 9.629842344783986e-07, 'lambda_l2': 6.918285700487489e-06}. Best is trial 0 with value: 0.7751074374089372.
# Early stopping, best iteration is:
# [14]	training's binary_logloss: 0.356256	valid_1's binary_logloss: 0.424982
# Fold 10 | AUC: 0.7771903463372104
# --------------------------------------------------------------------------------
#
# Mean AUC = 0.761981496921428
# OOF AUC = 0.7626329461353722
# fold: 1, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [83]	training's binary_logloss: 0.408729	valid_1's binary_logloss: 0.429517
# Fold 1 | AUC: 0.7617536001184615
# --------------------------------------------------------------------------------
# fold: 2, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# [200]	training's binary_logloss: 0.405992	valid_1's binary_logloss: 0.408611
# [400]	training's binary_logloss: 0.400065	valid_1's binary_logloss: 0.405999
# Early stopping, best iteration is:
# [350]	training's binary_logloss: 0.401352	valid_1's binary_logloss: 0.405578
# Fold 2 | AUC: 0.797727020323548
# --------------------------------------------------------------------------------
# fold: 3, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [90]	training's binary_logloss: 0.412079	valid_1's binary_logloss: 0.40023
# Fold 3 | AUC: 0.8045247517359815
# --------------------------------------------------------------------------------
# fold: 4, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [73]	training's binary_logloss: 0.409511	valid_1's binary_logloss: 0.436785
# Fold 4 | AUC: 0.7586425744792056
# --------------------------------------------------------------------------------
# fold: 5, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# [200]	training's binary_logloss: 0.404324	valid_1's binary_logloss: 0.418439
# Early stopping, best iteration is:
# [125]	training's binary_logloss: 0.407721	valid_1's binary_logloss: 0.417681
# Fold 5 | AUC: 0.7812992746767582
# --------------------------------------------------------------------------------
# fold: 6, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# [200]	training's binary_logloss: 0.404688	valid_1's binary_logloss: 0.418166
# Early stopping, best iteration is:
# [123]	training's binary_logloss: 0.408056	valid_1's binary_logloss: 0.417145
# Fold 6 | AUC: 0.7900087187192758
# --------------------------------------------------------------------------------
# fold: 7, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [76]	training's binary_logloss: 0.412062	valid_1's binary_logloss: 0.410818
# Fold 7 | AUC: 0.7899252416198268
# --------------------------------------------------------------------------------
# fold: 8, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [85]	training's binary_logloss: 0.409159	valid_1's binary_logloss: 0.428862
# Fold 8 | AUC: 0.7753724006158754
# --------------------------------------------------------------------------------
# fold: 9, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# [200]	training's binary_logloss: 0.405076	valid_1's binary_logloss: 0.416046
# [400]	training's binary_logloss: 0.399392	valid_1's binary_logloss: 0.415338
# Early stopping, best iteration is:
# [413]	training's binary_logloss: 0.3991	valid_1's binary_logloss: 0.415023
# Fold 9 | AUC: 0.7799543658523012
# --------------------------------------------------------------------------------
# [I 2021-03-22 02:42:26,844] Trial 2 finished with value: 0.7810843510832484 and parameters: {'num_leaves': 2, 'max_bin': 192, 'min_data_in_leaf': 26, 'feature_fraction': 0.94069732804307, 'bagging_fraction': 0.9759602211671502, 'bagging_freq': 4, 'lambda_l1': 2.2499339249159318e-08, 'lambda_l2': 1.8188273820076552e-08}. Best is trial 2 with value: 0.7810843510832484.
# fold: 10, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [89]	training's binary_logloss: 0.409867	valid_1's binary_logloss: 0.418089
# Fold 10 | AUC: 0.7803068247166416
# --------------------------------------------------------------------------------
#
# Mean AUC = 0.7819514772857875
# OOF AUC = 0.7810843510832484
# fold: 1, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [24]	training's binary_logloss: 0.328478	valid_1's binary_logloss: 0.43768
# Fold 1 | AUC: 0.7538037241328249
# --------------------------------------------------------------------------------
# fold: 2, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [21]	training's binary_logloss: 0.343833	valid_1's binary_logloss: 0.407998
# Fold 2 | AUC: 0.7975234146522044
# --------------------------------------------------------------------------------
# fold: 3, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [20]	training's binary_logloss: 0.349629	valid_1's binary_logloss: 0.4125
# Fold 3 | AUC: 0.7794930187411336
# --------------------------------------------------------------------------------
# fold: 4, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [15]	training's binary_logloss: 0.363925	valid_1's binary_logloss: 0.45148
# Fold 4 | AUC: 0.7290188904651683
# --------------------------------------------------------------------------------
# fold: 5, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [20]	training's binary_logloss: 0.349401	valid_1's binary_logloss: 0.429824
# Fold 5 | AUC: 0.7667278832062626
# --------------------------------------------------------------------------------
# fold: 6, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [34]	training's binary_logloss: 0.300373	valid_1's binary_logloss: 0.418156
# Fold 6 | AUC: 0.7962416754781383
# --------------------------------------------------------------------------------
# fold: 7, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [18]	training's binary_logloss: 0.354182	valid_1's binary_logloss: 0.422024
# Fold 7 | AUC: 0.7773387500695642
# --------------------------------------------------------------------------------
# fold: 8, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [14]	training's binary_logloss: 0.370618	valid_1's binary_logloss: 0.43774
# Fold 8 | AUC: 0.7635928543602871
# --------------------------------------------------------------------------------
# fold: 9, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [21]	training's binary_logloss: 0.34247	valid_1's binary_logloss: 0.411833
# Fold 9 | AUC: 0.7853525516166732
# --------------------------------------------------------------------------------
# fold: 10, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# [I 2021-03-22 02:42:30,070] Trial 3 finished with value: 0.7725262104948917 and parameters: {'num_leaves': 184, 'max_bin': 214, 'min_data_in_leaf': 34, 'feature_fraction': 0.5055089956436497, 'bagging_fraction': 0.5560510082561176, 'bagging_freq': 5, 'lambda_l1': 2.2291282059642755e-06, 'lambda_l2': 9.877441657254314e-06}. Best is trial 2 with value: 0.7810843510832484.
# Early stopping, best iteration is:
# [13]	training's binary_logloss: 0.374068	valid_1's binary_logloss: 0.426359
# Fold 10 | AUC: 0.7705492793143747
# --------------------------------------------------------------------------------
#
# Mean AUC = 0.7719642042036632
# OOF AUC = 0.7725262104948917
# fold: 1, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [20]	training's binary_logloss: 0.366439	valid_1's binary_logloss: 0.434771
# Fold 1 | AUC: 0.7632991522600231
# --------------------------------------------------------------------------------
# fold: 2, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [32]	training's binary_logloss: 0.342487	valid_1's binary_logloss: 0.412319
# Fold 2 | AUC: 0.7862695739088587
# --------------------------------------------------------------------------------
# fold: 3, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [26]	training's binary_logloss: 0.355971	valid_1's binary_logloss: 0.400745
# Fold 3 | AUC: 0.7992981408198312
# --------------------------------------------------------------------------------
# fold: 4, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [14]	training's binary_logloss: 0.384318	valid_1's binary_logloss: 0.444912
# Fold 4 | AUC: 0.7493840065705967
# --------------------------------------------------------------------------------
# fold: 5, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [20]	training's binary_logloss: 0.368465	valid_1's binary_logloss: 0.435841
# Fold 5 | AUC: 0.7586491550262489
# --------------------------------------------------------------------------------
# fold: 6, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [32]	training's binary_logloss: 0.339727	valid_1's binary_logloss: 0.412761
# Fold 6 | AUC: 0.7964457306101249
# --------------------------------------------------------------------------------
# fold: 7, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [35]	training's binary_logloss: 0.335075	valid_1's binary_logloss: 0.41855
# Fold 7 | AUC: 0.7837943124269576
# --------------------------------------------------------------------------------
# fold: 8, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [39]	training's binary_logloss: 0.323749	valid_1's binary_logloss: 0.433924
# Fold 8 | AUC: 0.768100617730536
# --------------------------------------------------------------------------------
# fold: 9, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [34]	training's binary_logloss: 0.338947	valid_1's binary_logloss: 0.409637
# Fold 9 | AUC: 0.7880980206652197
# --------------------------------------------------------------------------------
# fold: 10, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# [I 2021-03-22 02:42:32,486] Trial 4 finished with value: 0.7747038277199283 and parameters: {'num_leaves': 25, 'max_bin': 205, 'min_data_in_leaf': 23, 'feature_fraction': 0.9604607237414143, 'bagging_fraction': 0.4819274445055857, 'bagging_freq': 2, 'lambda_l1': 4.056811531724552e-07, 'lambda_l2': 3.41235692735172e-05}. Best is trial 2 with value: 0.7810843510832484.
# Early stopping, best iteration is:
# [21]	training's binary_logloss: 0.365111	valid_1's binary_logloss: 0.430912
# Fold 10 | AUC: 0.7622015693694697
# --------------------------------------------------------------------------------
#
# Mean AUC = 0.7755540279387866
# OOF AUC = 0.7747038277199283
# fold: 1, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [10]	training's binary_logloss: 0.386276	valid_1's binary_logloss: 0.452509
# Fold 1 | AUC: 0.7275108281197942
# --------------------------------------------------------------------------------
# fold: 2, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [19]	training's binary_logloss: 0.339535	valid_1's binary_logloss: 0.409827
# Fold 2 | AUC: 0.7911190908081294
# --------------------------------------------------------------------------------
# fold: 3, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [17]	training's binary_logloss: 0.351319	valid_1's binary_logloss: 0.41625
# Fold 3 | AUC: 0.774266407824983
# --------------------------------------------------------------------------------
# fold: 4, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [16]	training's binary_logloss: 0.352132	valid_1's binary_logloss: 0.445556
# Fold 4 | AUC: 0.7426547450160532
# --------------------------------------------------------------------------------
# fold: 5, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [14]	training's binary_logloss: 0.36689	valid_1's binary_logloss: 0.43736
# Fold 5 | AUC: 0.7536683547591222
# --------------------------------------------------------------------------------
# fold: 6, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [28]	training's binary_logloss: 0.303203	valid_1's binary_logloss: 0.423686
# Fold 6 | AUC: 0.7791752462574435
# --------------------------------------------------------------------------------
# fold: 7, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [29]	training's binary_logloss: 0.298696	valid_1's binary_logloss: 0.427346
# Fold 7 | AUC: 0.7759289146122025
# --------------------------------------------------------------------------------
# fold: 8, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [16]	training's binary_logloss: 0.352861	valid_1's binary_logloss: 0.44559
# Fold 8 | AUC: 0.7535385014933125
# --------------------------------------------------------------------------------
# fold: 9, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [20]	training's binary_logloss: 0.335067	valid_1's binary_logloss: 0.42131
# Fold 9 | AUC: 0.7704379765151094
# --------------------------------------------------------------------------------
# fold: 10, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# [I 2021-03-22 02:42:36,263] Trial 5 finished with value: 0.7636902401459085 and parameters: {'num_leaves': 183, 'max_bin': 172, 'min_data_in_leaf': 11, 'feature_fraction': 0.5051828613869401, 'bagging_fraction': 0.414723926976868, 'bagging_freq': 4, 'lambda_l1': 0.6060815805579127, 'lambda_l2': 0.5848303528032238}. Best is trial 2 with value: 0.7810843510832484.
# Early stopping, best iteration is:
# [13]	training's binary_logloss: 0.367473	valid_1's binary_logloss: 0.428384
# Fold 10 | AUC: 0.7706976830467287
# --------------------------------------------------------------------------------
#
# Mean AUC = 0.7638997748452878
# OOF AUC = 0.7636902401459085
# fold: 1, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [20]	training's binary_logloss: 0.361412	valid_1's binary_logloss: 0.438399
# Fold 1 | AUC: 0.7518694702550623
# --------------------------------------------------------------------------------
# fold: 2, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [25]	training's binary_logloss: 0.350766	valid_1's binary_logloss: 0.408354
# Fold 2 | AUC: 0.7963850738533299
# --------------------------------------------------------------------------------
# fold: 3, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [34]	training's binary_logloss: 0.328695	valid_1's binary_logloss: 0.408145
# Fold 3 | AUC: 0.7898902411707608
# --------------------------------------------------------------------------------
# fold: 4, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [14]	training's binary_logloss: 0.383587	valid_1's binary_logloss: 0.443271
# Fold 4 | AUC: 0.7508679907414321
# --------------------------------------------------------------------------------
# fold: 5, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [22]	training's binary_logloss: 0.356157	valid_1's binary_logloss: 0.425089
# Fold 5 | AUC: 0.7726454820338732
# --------------------------------------------------------------------------------
# fold: 6, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [26]	training's binary_logloss: 0.347231	valid_1's binary_logloss: 0.414847
# Fold 6 | AUC: 0.7908620401803105
# --------------------------------------------------------------------------------
# fold: 7, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [24]	training's binary_logloss: 0.350848	valid_1's binary_logloss: 0.421606
# Fold 7 | AUC: 0.7752425473500658
# --------------------------------------------------------------------------------
# fold: 8, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [38]	training's binary_logloss: 0.315947	valid_1's binary_logloss: 0.440793
# Fold 8 | AUC: 0.7625540282338101
# --------------------------------------------------------------------------------
# fold: 9, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [23]	training's binary_logloss: 0.35568	valid_1's binary_logloss: 0.408033
# Fold 9 | AUC: 0.7859832674791771
# --------------------------------------------------------------------------------
# fold: 10, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# [I 2021-03-22 02:42:39,519] Trial 6 finished with value: 0.7740848605151649 and parameters: {'num_leaves': 51, 'max_bin': 163, 'min_data_in_leaf': 11, 'feature_fraction': 0.9635791533269867, 'bagging_fraction': 0.7851298836678307, 'bagging_freq': 6, 'lambda_l1': 3.922611370804397, 'lambda_l2': 0.0002264765040363003}. Best is trial 2 with value: 0.7810843510832484.
# Early stopping, best iteration is:
# [17]	training's binary_logloss: 0.373563	valid_1's binary_logloss: 0.426638
# Fold 10 | AUC: 0.7714582521750423
# --------------------------------------------------------------------------------
#
# Mean AUC = 0.7747758393472864
# OOF AUC = 0.7740848605151649
# fold: 1, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [23]	training's binary_logloss: 0.302749	valid_1's binary_logloss: 0.437437
# Fold 1 | AUC: 0.7568392995964905
# --------------------------------------------------------------------------------
# fold: 2, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [18]	training's binary_logloss: 0.331954	valid_1's binary_logloss: 0.417427
# Fold 2 | AUC: 0.7811239033058157
# --------------------------------------------------------------------------------
# fold: 3, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [16]	training's binary_logloss: 0.344783	valid_1's binary_logloss: 0.416315
# Fold 3 | AUC: 0.7782423654147689
# --------------------------------------------------------------------------------
# fold: 4, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [11]	training's binary_logloss: 0.36861	valid_1's binary_logloss: 0.451326
# Fold 4 | AUC: 0.7404241021429105
# --------------------------------------------------------------------------------
# fold: 5, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [19]	training's binary_logloss: 0.327448	valid_1's binary_logloss: 0.427342
# Fold 5 | AUC: 0.7643534234886007
# --------------------------------------------------------------------------------
# fold: 6, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [23]	training's binary_logloss: 0.309254	valid_1's binary_logloss: 0.413569
# Fold 6 | AUC: 0.7953883540171034
# --------------------------------------------------------------------------------
# fold: 7, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [18]	training's binary_logloss: 0.331032	valid_1's binary_logloss: 0.416407
# Fold 7 | AUC: 0.7886174337284582
# --------------------------------------------------------------------------------
# fold: 8, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [16]	training's binary_logloss: 0.340443	valid_1's binary_logloss: 0.435671
# Fold 8 | AUC: 0.7666536813400856
# --------------------------------------------------------------------------------
# fold: 9, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [16]	training's binary_logloss: 0.340722	valid_1's binary_logloss: 0.41556
# Fold 9 | AUC: 0.7838685142931345
# --------------------------------------------------------------------------------
# fold: 10, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# [I 2021-03-22 02:42:43,272] Trial 7 finished with value: 0.7712856769429333 and parameters: {'num_leaves': 163, 'max_bin': 197, 'min_data_in_leaf': 38, 'feature_fraction': 0.6639191160129649, 'bagging_fraction': 0.7966384676328934, 'bagging_freq': 5, 'lambda_l1': 0.002726739408134978, 'lambda_l2': 0.016434320650842087}. Best is trial 2 with value: 0.7810843510832484.
# Early stopping, best iteration is:
# [15]	training's binary_logloss: 0.345994	valid_1's binary_logloss: 0.428898
# Fold 10 | AUC: 0.7585842283933439
# --------------------------------------------------------------------------------
#
# Mean AUC = 0.7714095305720712
# OOF AUC = 0.7712856769429333
# fold: 1, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [13]	training's binary_logloss: 0.380733	valid_1's binary_logloss: 0.43807
# Fold 1 | AUC: 0.7547292044571132
# --------------------------------------------------------------------------------
# fold: 2, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [19]	training's binary_logloss: 0.368875	valid_1's binary_logloss: 0.41455
# Fold 2 | AUC: 0.7826602006441342
# --------------------------------------------------------------------------------
# fold: 3, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [17]	training's binary_logloss: 0.37576	valid_1's binary_logloss: 0.415729
# Fold 3 | AUC: 0.77992234749496
# --------------------------------------------------------------------------------
# fold: 4, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [23]	training's binary_logloss: 0.347333	valid_1's binary_logloss: 0.450705
# Fold 4 | AUC: 0.7385014559844696
# --------------------------------------------------------------------------------
# fold: 5, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [12]	training's binary_logloss: 0.395752	valid_1's binary_logloss: 0.438105
# Fold 5 | AUC: 0.7605320273804886
# --------------------------------------------------------------------------------
# fold: 6, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [20]	training's binary_logloss: 0.362934	valid_1's binary_logloss: 0.427441
# Fold 6 | AUC: 0.7712912979761442
# --------------------------------------------------------------------------------
# fold: 7, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [26]	training's binary_logloss: 0.346062	valid_1's binary_logloss: 0.412699
# Fold 7 | AUC: 0.790973342979576
# --------------------------------------------------------------------------------
# fold: 8, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [20]	training's binary_logloss: 0.359609	valid_1's binary_logloss: 0.435879
# Fold 8 | AUC: 0.7665423785408203
# --------------------------------------------------------------------------------
# fold: 9, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [21]	training's binary_logloss: 0.360063	valid_1's binary_logloss: 0.416124
# Fold 9 | AUC: 0.7769306398055911
# --------------------------------------------------------------------------------
# fold: 10, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# [I 2021-03-22 02:42:46,044] Trial 8 finished with value: 0.7685925940778169 and parameters: {'num_leaves': 70, 'max_bin': 158, 'min_data_in_leaf': 31, 'feature_fraction': 0.6530059570517455, 'bagging_fraction': 0.4154408788472055, 'bagging_freq': 6, 'lambda_l1': 1.356350510938406e-06, 'lambda_l2': 4.128973111439156e-06}. Best is trial 2 with value: 0.7810843510832484.
# Early stopping, best iteration is:
# [14]	training's binary_logloss: 0.37756	valid_1's binary_logloss: 0.423816
# Fold 10 | AUC: 0.7753167492162427
# --------------------------------------------------------------------------------
#
# Mean AUC = 0.769739964447954
# OOF AUC = 0.7685925940778169
# fold: 1, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [15]	training's binary_logloss: 0.339931	valid_1's binary_logloss: 0.450242
# Fold 1 | AUC: 0.7298430385370007
# --------------------------------------------------------------------------------
# fold: 2, x_tr.shape: (5149, 21), x_val.shape: (573, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [23]	training's binary_logloss: 0.302167	valid_1's binary_logloss: 0.412457
# Fold 2 | AUC: 0.7873061118720617
# --------------------------------------------------------------------------------
# fold: 3, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [17]	training's binary_logloss: 0.334323	valid_1's binary_logloss: 0.408776
# Fold 3 | AUC: 0.7921115508101247
# --------------------------------------------------------------------------------
# fold: 4, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [12]	training's binary_logloss: 0.360285	valid_1's binary_logloss: 0.455697
# Fold 4 | AUC: 0.7242029418352871
# --------------------------------------------------------------------------------
# fold: 5, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [18]	training's binary_logloss: 0.327213	valid_1's binary_logloss: 0.426263
# Fold 5 | AUC: 0.7695475541209862
# --------------------------------------------------------------------------------
# fold: 6, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [21]	training's binary_logloss: 0.311882	valid_1's binary_logloss: 0.414194
# Fold 6 | AUC: 0.7937744634277553
# --------------------------------------------------------------------------------
# fold: 7, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [26]	training's binary_logloss: 0.287146	valid_1's binary_logloss: 0.42296
# Fold 7 | AUC: 0.7773016491364758
# --------------------------------------------------------------------------------
# fold: 8, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [15]	training's binary_logloss: 0.342147	valid_1's binary_logloss: 0.441052
# Fold 8 | AUC: 0.7562097686756822
# --------------------------------------------------------------------------------
# fold: 9, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [24]	training's binary_logloss: 0.297766	valid_1's binary_logloss: 0.41227
# Fold 9 | AUC: 0.7839612666258557
# --------------------------------------------------------------------------------
# fold: 10, x_tr.shape: (5150, 21), x_val.shape: (572, 21)
# Training until validation scores don't improve for 100 rounds
# [I 2021-03-22 02:42:50,040] Trial 9 finished with value: 0.7670161213665845 and parameters: {'num_leaves': 244, 'max_bin': 213, 'min_data_in_leaf': 40, 'feature_fraction': 0.771342652965983, 'bagging_fraction': 0.8727079829358828, 'bagging_freq': 3, 'lambda_l1': 0.24566953051363571, 'lambda_l2': 0.0012964823688713378}. Best is trial 2 with value: 0.7810843510832484.
# Early stopping, best iteration is:
# [14]	training's binary_logloss: 0.349162	valid_1's binary_logloss: 0.434749
# Fold 10 | AUC: 0.7520173632366853
# --------------------------------------------------------------------------------
#
# Mean AUC = 0.7666275708277914
# OOF AUC = 0.7670161213665845

# %% [markdown]
# ## Validation 스코어가 가장 잘 나온 하이퍼 파라미터 출력

# %%
study.best_params
# Out:
# {'num_leaves': 2,
#  'max_bin': 192,
#  'min_data_in_leaf': 26,
#  'feature_fraction': 0.94069732804307,
#  'bagging_fraction': 0.9759602211671502,
#  'bagging_freq': 4,
#  'lambda_l1': 2.2499339249159318e-08,
#  'lambda_l2': 1.8188273820076552e-08}

# %% [markdown]
# ## 가장 성능이 잘 나온 Validation 스코어 출력

# %%
study.best_value
# Out:
# 0.7810843510832484

# %% [markdown]
# ## 하이퍼 파라미터 탐색 관련한 전체 데이터를 판다스 데이터 프레임으로 보기

# %%
study.trials_dataframe()
# Out:
#    number     value             datetime_start          datetime_complete  \
# 0       0  0.775107 2021-03-22 02:42:18.736500 2021-03-22 02:42:21.149660
# 1       1  0.762633 2021-03-22 02:42:21.150669 2021-03-22 02:42:25.112071
# 2       2  0.781084 2021-03-22 02:42:25.113022 2021-03-22 02:42:26.844559
# 3       3  0.772526 2021-03-22 02:42:26.845521 2021-03-22 02:42:30.069776
# 4       4  0.774704 2021-03-22 02:42:30.070725 2021-03-22 02:42:32.486264
# 5       5  0.763690 2021-03-22 02:42:32.487231 2021-03-22 02:42:36.263367
# 6       6  0.774085 2021-03-22 02:42:36.264379 2021-03-22 02:42:39.518680
# 7       7  0.771286 2021-03-22 02:42:39.519623 2021-03-22 02:42:43.271643
# 8       8  0.768593 2021-03-22 02:42:43.272595 2021-03-22 02:42:46.043879
# 9       9  0.767016 2021-03-22 02:42:46.044856 2021-03-22 02:42:50.040082
#
#                 duration  params_bagging_fraction  params_bagging_freq  \
# 0 0 days 00:00:02.413160                 0.418537                    6
# 1 0 days 00:00:03.961402                 0.434584                    6
# 2 0 days 00:00:01.731537                 0.975960                    4
# 3 0 days 00:00:03.224255                 0.556051                    5
# 4 0 days 00:00:02.415539                 0.481927                    2
# 5 0 days 00:00:03.776136                 0.414724                    4
# 6 0 days 00:00:03.254301                 0.785130                    6
# 7 0 days 00:00:03.752020                 0.796638                    5
# 8 0 days 00:00:02.771284                 0.415441                    6
# 9 0 days 00:00:03.995226                 0.872708                    3
#
#    params_feature_fraction  params_lambda_l1  params_lambda_l2  \
# 0                 0.904890      1.490543e+00      1.570832e-08
# 1                 0.635856      9.629842e-07      6.918286e-06
# 2                 0.940697      2.249934e-08      1.818827e-08
# 3                 0.505509      2.229128e-06      9.877442e-06
# 4                 0.960461      4.056812e-07      3.412357e-05
# 5                 0.505183      6.060816e-01      5.848304e-01
# 6                 0.963579      3.922611e+00      2.264765e-04
# 7                 0.663919      2.726739e-03      1.643432e-02
# 8                 0.653006      1.356351e-06      4.128973e-06
# 9                 0.771343      2.456695e-01      1.296482e-03
#
#    params_max_bin  params_min_data_in_leaf  params_num_leaves     state
# 0             150                       39                 54  COMPLETE
# 1             254                       20                162  COMPLETE
# 2             192                       26                  2  COMPLETE
# 3             214                       34                184  COMPLETE
# 4             205                       23                 25  COMPLETE
# 5             172                       11                183  COMPLETE
# 6             163                       11                 51  COMPLETE
# 7             197                       38                163  COMPLETE
# 8             158                       31                 70  COMPLETE
# 9             213                       40                244  COMPLETE

# %% [markdown]
# ## 하이퍼 파라미터 중요도 Visualization

# %%
optuna.visualization.matplotlib.plot_param_importances(study)
plt.show()

# %% [markdown]
# ## 하이퍼 파라미터 탐색 히스토리 Visualization

# %%
optuna.visualization.matplotlib.plot_optimization_history(study)
plt.show()

# %% [markdown]
# ## 하이퍼 파라미터별 Validation 스코어의 관계 Visualization

# %%
optuna.visualization.matplotlib.plot_slice(study)
plt.show()

# %% [markdown]
# ## 하이퍼 파라미터 Contour Visualization

# %%
optuna.visualization.matplotlib.plot_contour(study, params=['num_leaves','min_data_in_leaf'])
plt.show()
# Out:
# [W 2021-03-22 02:42:51,649] Output figures of this Matplotlib-based `plot_contour` function would be different from those of the Plotly-based `plot_contour`.

# %% [markdown]
# ## 하이퍼 파라미터 Parallel Coodinate Visualization

# %%
optuna.visualization.matplotlib.plot_parallel_coordinate(study, params=['num_leaves','min_data_in_leaf'])
plt.show()
